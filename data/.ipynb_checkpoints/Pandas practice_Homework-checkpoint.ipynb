# %% [markdown]
# # IMPORT DATA

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # READ DATA

# %%
pd.read_csv("./t2020.csv")
# Out:
#      StateAbbr    StateDesc CountyName  CountyFIPS TotalPopulation  \
# 0           OK     Oklahoma    Jackson       40065          24,949
# 1           IL     Illinois   Lawrence       17101          15,765
# 2           KS       Kansas     Barton       20009          26,111
# 3           AK       Alaska  Anchorage        2020         291,538
# 4           OK     Oklahoma   Stephens       40137          43,265
# ...        ...          ...        ...         ...             ...
# 3137        KY     Kentucky     Carter       21043          27,004
# 3138        MS  Mississippi     DeSoto       28033         182,001
# 3139        NY     New York   Richmond       36085         476,179
# 3140        KS       Kansas     Saline       20169          54,401
# 3141        TX        Texas       Wise       48497          68,305
#
#       ACCESS2_CrudePrev ACCESS2_Crude95CI  ACCESS2_AdjPrev ACCESS2_Adj95CI  \
# 0                  20.7      (18.3, 23.4)             20.9    (18.5, 23.7)
# ...

# %% [markdown]
# # Run Descriptives

# %%
Descriptive_list=pd.read_csv("./t2020.csv")

# %%
Descriptive_list.head
# Out:
# <bound method NDFrame.head of      StateAbbr    StateDesc CountyName  CountyFIPS TotalPopulation  \
# 0           OK     Oklahoma    Jackson       40065          24,949
# 1           IL     Illinois   Lawrence       17101          15,765
# 2           KS       Kansas     Barton       20009          26,111
# 3           AK       Alaska  Anchorage        2020         291,538
# 4           OK     Oklahoma   Stephens       40137          43,265
# ...        ...          ...        ...         ...             ...
# 3137        KY     Kentucky     Carter       21043          27,004
# 3138        MS  Mississippi     DeSoto       28033         182,001
# 3139        NY     New York   Richmond       36085         476,179
# 3140        KS       Kansas     Saline       20169          54,401
# 3141        TX        Texas       Wise       48497          68,305
#
#       ACCESS2_CrudePrev ACCESS2_Crude95CI  ACCESS2_AdjPrev ACCESS2_Adj95CI  \
# ...

# %%
Descriptive_list.StateAbbr
# Out:
# 0       OK
# 1       IL
# 2       KS
# 3       AK
# 4       OK
#         ..
# 3137    KY
# 3138    MS
# 3139    NY
# 3140    KS
# 3141    TX
# Name: StateAbbr, Length: 3142, dtype: object

# %%
Descriptive_list.StateAbbr.value_counts()
#the frequency of each state in the file
# Out:
# TX    254
# GA    159
# VA    133
# KY    120
# MO    115
# KS    105
# IL    102
# NC    100
# IA     99
# TN     95
# NE     93
# IN     92
# OH     88
# MN     87
# MI     83
# MS     82
# OK     77
# AR     75
# WI     72
# PA     67
# FL     67
# AL     67
# SD     66
# LA     64
# CO     64
# NY     62
# CA     58
# MT     56
# WV     55
# ND     53
# SC     46
# ID     44
# WA     39
# OR     36
# NM     33
# AK     29
# UT     29
# MD     24
# WY     23
# NJ     21
# NV     17
# ME     16
# AZ     15
# MA     14
# VT     14
# NH     10
# CT      8
# HI      5
# RI      5
# DE      3
# DC      1
# Name: StateAbbr, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### Thanks for your patience

# %% [markdown]
# ##### Wenhui Song
